# %% [markdown]
# <h1 style='color:Blue'>LLM</h1>

# %% [markdown]
# - ## LLM are based on transformer architecture

# %% [markdown]
# <h1 style='color:green'>Transformer Model</h1>

# %% [markdown]
# ### Paper Name: Attention is all you need

# %%
from IPython.display import IFrame
IFrame("Transforner_Architecture.pdf", width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Transforner_Architecture.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1 style='color:green'>Self Attention</h1>

# %% [markdown]
# ### Follow: https://youtu.be/SO2-3YS6e-k?si=ZZ1I6-R0E011S7Bk

# %%
from IPython.display import IFrame
IFrame("Self_Attention.pdf", width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Self_Attention.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1 style='color:green'>Linear Transformation in Self Attention</h1>

# %%
from IPython.display import IFrame
IFrame("Linear_Transformation_in_Self_Attention.pdf", width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Linear_Transformation_in_Self_Attention.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1 style='color:green'>Query, Key and Value</h1>

# %% [markdown]
# <img src='Query_Key_Value.png'>

# %% [markdown]
# <h1 style='color:red'>Why Scaling by the Square root of Dimentions?</h1>

# %%
from IPython.display import IFrame
IFrame("Why_scaling_by_the_squre_root_of_dimentions.pdf", width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Why_scaling_by_the_squre_root_of_dimentions.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1 style='color:green'>Multi-head Attention</h1>

# %%
from IPython.display import IFrame
IFrame('Self_Attention.pdf', width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Self_Attention.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <h1 style='color:green'>Positional Embedding</h1>

# %%
from IPython.display import IFrame
IFrame('Positional_Embedding.pdf', width=600, height=700)
# Out:
#         <iframe
#             width="600"
#             height="700"
#             src="Positional_Embedding.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
