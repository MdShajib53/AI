# %% [markdown]
# <h1 style="color:green;">Natural Language Processing (NLP)</h1>

# %% [markdown]
# - ### A field of AI that allows computers to understand, interpret, and generate human language data
# - #### 1950: First traces of NLP
# - #### 1990: Booming development of the web
# - #### 2012: Massive advances in technology and availability of large datasets
# - #### 2023: ChatGPT

# %% [markdown]
# <h2 style="color: blue"}> Quality of the data is one of the most important factors that determines the accuracy</h2>

# %% [markdown]
# <h1 style="color: green">Data Preprocessing</h1>

# %% [markdown]
# ## 1. General Cleaning
# - ### Organizing
# - ### Tidying up the text
# - ### Remove anything that can throw an error
# ## 2. Removing Noise from the Dataset
# - ### Removing aspects in the data that are not adding any value
# ## 3. Getting the data in the right format for the ML Algorithm

# %% [markdown]
# # Ex:
# #### The quic brown fox jumps over the lazy dog
# <pre>          <strong> ↓ </strong>      </pre>
# #### [quick, brown, fox, lump, lazy, dog]

# %% [markdown]
# <h1 style="color:green"}>Setting up the environment</h1>

# %% [markdown]
# - #### Goto Anaconda promot
# - #### conda create --name nlp_course_env python-3.11
# - #### conda activate nlp_course_env
# - #### pip install "numpy<2.0" nltk==3.9.1 pandas==2.2.3 matplotlib==3.10.0 spacy==3.8.3 textblob==0.18.0.post0 vaderSentiment==3.3.2 transformers==4.47.1 scikit-learn==1.6.0 gensim==4.3.3 seaborn==0.13.2 torch==2.5.1 ipywidgets==8.1.5 chardet ipykernel jupyterlab notebook
# - #### python -m spacy download en_core_web_sm
# - #### python -m ipykernel install --user --name=nlp_course_env
